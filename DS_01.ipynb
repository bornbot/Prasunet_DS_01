# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
d1= pd.read_csv(r"C:\Users\HP\Downloads\INTERNSHIP\D1.csv")
d1.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
d2= pd.read_csv(r"C:\Users\HP\Downloads\INTERNSHIP\D2.csv")
d2.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
d3= pd.read_csv(r"C:\Users\HP\Downloads\INTERNSHIP\Metadata_Indicator_API.csv")
d3.head()
# Out:
#   INDICATOR_CODE     INDICATOR_NAME  \
# 0    SP.POP.TOTL  Population, total
#
#                                          SOURCE_NOTE  \
# 0  Total population is based on the de facto defi...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  (1) United Nations Population Division. World ...         NaN

# %%
# Select the year 2020 data from D1
year = '2020'
population_2020_d1 = d1[['Country Name', year]].dropna()

# Create a histogram for D1 population data in 2020
plt.figure(figsize=(10, 6))
plt.hist(population_2020_d1[year], bins=30, edgecolor='black')
plt.title('Distribution of Population by Country in 2020 (D1)')
plt.xlabel('Population')
plt.ylabel('Number of Countries')
plt.yscale('log')  # Use log scale for better visibility of distribution
plt.grid(True)
plt.show()

# %%
# Find the top 10 populated countries in 2020 from D1 dataset
top_10_countries_d1 = population_2020_d1.sort_values(by=year, ascending=False).head(10)

# Plot population trends for the top 10 populated countries from D1 data
plt.figure(figsize=(12, 8))

for index, row in top_10_countries_d1.iterrows():
    country_data = d1[d1['Country Name'] == row['Country Name']]
    plt.plot(decades, country_data[decades].values[0], label=row['Country Name'], linewidth=2)

plt.title('Population Trends Over Decades for Top 10 Populated Countries in 2020 (D1)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
# Calculate the total population for each country in the most recent year available (2020)
total_population_2020 = d1[['Country Name', '2020']].dropna()

# Find the top 10 countries by population in 2020
top_10_population_countries_2020 = total_population_2020.sort_values(by='2020', ascending=False).head(10)

# Plot a pie chart for the population of the top 10 countries in 2020
plt.figure(figsize=(12, 8))
plt.pie(top_10_population_countries_2020['2020'], labels=top_10_population_countries_2020['Country Name'], autopct='%1.1f%%', startangle=140)
plt.title('Population Distribution of Top 10 Countries in 2020')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
